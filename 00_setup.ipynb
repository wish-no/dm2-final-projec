# %%
catalog = "workspace"
schema  = "dm2_project"

spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.{schema}")
for v in ["landing", "reference", "chk"]:
    spark.sql(f"CREATE VOLUME IF NOT EXISTS {catalog}.{schema}.{v}")

print("Setup done:", catalog, schema)
